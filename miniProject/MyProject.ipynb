# %%
#Import Python Libraries
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
#Read csv file
df = pd.read_csv('Salaries.csv')
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %% [raw]
# Exploring Data Frame

# %%
#List the First 5 records
Firstfive = df.head()
Firstfive
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
#List the Last 5 records
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
#List the First 35 records
df.head(35)
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750
# 15       Prof          B   17        3  Male  150480
# 16   AsstProf          B    8        3  Male   75044
# ...

# %% [raw]
# Data Frame data types

# %%
#Check a particular column type
df['salary'].dtype
# Out:
# dtype('int64')

# %%
#Check types for all the columns
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %% [markdown]
# Data Frame attributes

# %%
#Lists the column names
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
#Listing the row labels and column names
df.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
#Number of dimension the DataFanme has
df.ndim
# Out:
# 2

# %%
#The number of Elements in th dataframe
df.size
# Out:
# 468

# %%
#Shape returns a tuple representing the dimensionality
df.shape
# Out:
# (78, 6)

# %%
#numpy representation of the data
df.values
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %% [markdown]
# Data Frame Methods - Unlike attributes, python methods have parenthesis.

# %%
#head([n]), tail([n]) - Returns the first/last n rows
df.tail(15)
# Out:
#          rank discipline  phd  service     sex  salary
# 63       Prof          A   29       27  Female   91000
# 64  AssocProf          A   26       24  Female   73300
# 65       Prof          A   36       19  Female  117555
# 66   AsstProf          A    7        6  Female   63100
# 67       Prof          A   17       11  Female   90450
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
#describe() generate descriptive statistics (for numeric columns only)
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
#Calculate the mean for all numerical columns
df.mean()
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %% [markdown]
# Exercise:
# 1. Calculate the Standard Deviation
# 2. What is the average value of the first 50 records in the dataset?

# %%
#Standard Deviation
df.std()
# Out:
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
#Average value of the first 50 records
df.head(50).mean()
# Out:
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
#ALT2:
First50 = df.head(50)
First50
First50.mean()
# Out:
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
#Sample([n])- Returns a random sample of the data frame
df.sample()
# Out:
#     rank discipline  phd  service     sex  salary
# 67  Prof          A   17       11  Female   90450

# %%
#median()-return median values for all numeric columns
df.median()
# Out:
# phd            18.5
# service        14.5
# salary     104671.0
# dtype: float64

# %% [markdown]
# Selecting a column in a Data Frame

# %%
#Method 1:Subset the data frame using column name:
df['rank'].head(10)
# Out:
# 0         Prof
# 1         Prof
# 2         Prof
# 3         Prof
# 4         Prof
# 5         Prof
# 6    AssocProf
# 7         Prof
# 8         Prof
# 9         Prof
# Name: rank, dtype: object

# %%
#Method 2:Using column name as an attribute:
df.sex.tail(15)
# Out:
# 63    Female
# 64    Female
# 65    Female
# 66    Female
# 67    Female
# 68    Female
# 69    Female
# 70    Female
# 71    Female
# 72    Female
# 73    Female
# 74    Female
# 75    Female
# 76    Female
# 77    Female
# Name: sex, dtype: object

# %% [markdown]
# Exercise2:
# 1.Calculate the basic statistics for the salary column.
# 2.Find how many values in the salary column.
# 3.Calculate the average salary.

# %%
#The basic statistics for the salary column.
df.salary.describe()
# Out:
# count        78.000000
# mean     108023.782051
# std       28293.661022
# min       57800.000000
# 25%       88612.500000
# 50%      104671.000000
# 75%      126774.750000
# max      186960.000000
# Name: salary, dtype: float64

# %%
#How many values in the salary column.
df['salary'].count()
# Out:
# 78

# %%
#Calculate the average salary.
df.salary.mean()
# Out:
# 108023.78205128205

# %% [markdown]
# Data Frames groupby method
# Using "group by" method we can:
# • Split the data into groups based on some criteria
# • Calculate statistics (or apply a function) to each group
# • Similar to dplyr() function in R

# %%
#Group data using rank
df_rank = df.groupby(['rank'])

# %%
#Calculate mean value for each numeric column for the grouped object
df_rank.mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
#Group data using sex
df.groupby('sex').mean()
# Out:
#               phd    service         salary
# sex
# Female  16.512821  11.564103  101002.410256
# Male    22.897436  18.538462  115045.153846

# %%
#Group data using sex
df.groupby('discipline').mean()
# Out:
#                   phd    service         salary
# discipline
# A           21.527778  15.722222   98331.111111
# B           18.142857  14.476190  116331.785714

# %%
#Calculate the mean salary for men and women. The following produce Pandas Series (single brackets around salary)
df.groupby('rank')['salary'].mean()
# Out:
# rank
# AssocProf     91786.230769
# AsstProf      81362.789474
# Prof         123624.804348
# Name: salary, dtype: float64

# %%
# Group using 2 variables - sex and rank:
df.groupby(['rank','sex'], sort=True)[['salary']].mean()
# Out:
#                          salary
# rank      sex
# AssocProf Female   88512.800000
#           Male    102697.666667
# AsstProf  Female   78049.909091
#           Male     85918.000000
# Prof      Female  121967.611111
#           Male    124690.142857

# %% [markdown]
# ##Data Frame: filtering

# %%
#Calculate mean salary for each professor rank:
df_sub = df[ df['salary'] > 120000 ]
df_sub
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
#Select only those rows that contain female professors:
df_female = df[ df['sex'] == 'Female']
df_female.head()
# Out:
#          rank discipline  phd  service     sex  salary
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000

# %%
df_female.count()
# Out:
# rank          39
# discipline    39
# phd           39
# service       39
# sex           39
# salary        39
# dtype: int64

# %% [markdown]
# #Data Frames: Slicing

# %%
df_rs = df[['rank','salary']]
df_rs.head(10)
# Out:
#         rank  salary
# 0       Prof  186960
# 1       Prof   93000
# 2       Prof  110515
# 3       Prof  131205
# 4       Prof  104800
# 5       Prof  122400
# 6  AssocProf   81285
# 7       Prof  126300
# 8       Prof   94350
# 9       Prof   57800

# %%
#Selecting rows by thier position
df[10:20]
# Out:
#         rank discipline  phd  service   sex  salary
# 10      Prof          B   39       33  Male  128250
# 11      Prof          B   23       23  Male  134778
# 12  AsstProf          B    1        0  Male   88000
# 13      Prof          B   35       33  Male  162200
# 14      Prof          B   25       19  Male  153750
# 15      Prof          B   17        3  Male  150480
# 16  AsstProf          B    8        3  Male   75044
# 17  AsstProf          B    4        0  Male   92000
# 18      Prof          A   19        7  Male  107300
# 19      Prof          A   29       27  Male  150500

# %% [markdown]
# ## Method loc - select a range of rows using thier labels
# ## Method iloc selects rows (and columns) by poistion:

# %%
# Method .loc subset the data frame based on the labels:
df_sub = df.loc[20:30,['rank', 'sex', 'salary']]
df_sub
# Out:
#          rank   sex  salary
# 20   AsstProf  Male   92000
# 21       Prof  Male  103106
# 22   AsstProf  Male   73000
# 23   AsstProf  Male   85000
# 24       Prof  Male   91100
# 25       Prof  Male   99418
# 26       Prof  Male  148750
# 27       Prof  Male  155865
# 28   AsstProf  Male   91300
# 29       Prof  Male  123683
# 30  AssocProf  Male  107008

# %%
# Unlike method .loc, method iloc selects rows (and columns) by poistion:
df_sub2 = df.iloc[10:20, [0,1,4,5]]
df_sub2
# Out:
#         rank discipline   sex  salary
# 10      Prof          B  Male  128250
# 11      Prof          B  Male  134778
# 12  AsstProf          B  Male   88000
# 13      Prof          B  Male  162200
# 14      Prof          B  Male  153750
# 15      Prof          B  Male  150480
# 16  AsstProf          B  Male   75044
# 17  AsstProf          B  Male   92000
# 18      Prof          A  Male  107300
# 19      Prof          A  Male  150500

# %%
#First row of a data frame
df_f =df.iloc[0]
df_f
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           49
# sex             Male
# salary        186960
# Name: 0, dtype: object

# %%
#Last row of a data frame
df_l = df.iloc[-1]
df_l
# Out:
# rank            Prof
# discipline         A
# phd               23
# service           15
# sex           Female
# salary        109646
# Name: 77, dtype: object

# %%
#First column of a data frame
df_fc =df.iloc[:, 0]
df_fc
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
# 5          Prof
# 6     AssocProf
# 7          Prof
# 8          Prof
# 9          Prof
# 10         Prof
# 11         Prof
# 12     AsstProf
# 13         Prof
# 14         Prof
# 15         Prof
# 16     AsstProf
# 17     AsstProf
# 18         Prof
# 19         Prof
# 20     AsstProf
# 21         Prof
# 22     AsstProf
# 23     AsstProf
# 24         Prof
# 25         Prof
# 26         Prof
# 27         Prof
# 28     AsstProf
# 29         Prof
#         ...
# 48         Prof
# 49         Prof
# 50     AsstProf
# 51         Prof
# 52         Prof
# 53     AsstProf
# 54    AssocProf
# 55     AsstProf
# 56    AssocProf
# 57     AsstProf
# 58         Prof
# 59    AssocProf
# 60     AsstProf
# 61    AssocProf
# 62    AssocProf
# 63         Prof
# 64    AssocProf
# 65         Prof
# 66     AsstProf
# 67         Prof
# 68     AsstProf
# 69         Prof
# 70     AsstProf
# 71    AssocProf
# ...

# %%
#First row of a data frame
df_lc =df.iloc[:, -1]
df_lc
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
# 5     122400
# 6      81285
# 7     126300
# 8      94350
# 9      57800
# 10    128250
# 11    134778
# 12     88000
# 13    162200
# 14    153750
# 15    150480
# 16     75044
# 17     92000
# 18    107300
# 19    150500
# 20     92000
# 21    103106
# 22     73000
# 23     85000
# 24     91100
# 25     99418
# 26    148750
# 27    155865
# 28     91300
# 29    123683
#        ...
# 48    111512
# 49    122960
# 50     97032
# 51    127512
# 52    105000
# 53     73500
# 54     62884
# 55     72500
# 56     77500
# 57     72500
# 58    144651
# 59    103994
# 60     92000
# 61    103750
# 62    109650
# 63     91000
# 64     73300
# 65    117555
# 66     63100
# 67     90450
# 68     77500
# 69    116450
# 70     78500
# 71     71065
# 72    161101
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
#First 10 columns
df_first = df.iloc[0:10]
df_first
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
#1st and 6th rows and 2nd and 4th columns
df_slice = df.iloc[[0,5], [1,3]] 
df_slice
# Out:
#   discipline  service
# 0          B       49
# 5          A       20

# %% [markdown]
# ## Sorting Data
# ##Sort data by a value in the column

# %%
#Sort the df by years in service 
df_sorted = df.sort_values(by = 'service')
df_sorted.head(10)
# Out:
#         rank discipline  phd  service     sex  salary
# 55  AsstProf          A    2        0  Female   72500
# 23  AsstProf          A    2        0    Male   85000
# 43  AsstProf          B    5        0  Female   77000
# 17  AsstProf          B    4        0    Male   92000
# 12  AsstProf          B    1        0    Male   88000
# 52      Prof          A   12        0  Female  105000
# 57  AsstProf          A    3        1  Female   72500
# 28  AsstProf          B    7        2    Male   91300
# 42  AsstProf          B    4        2  Female   80225
# 22  AsstProf          A    4        2    Male   73000

# %%
#Sort the data frame by yrs.service and overwrite the original dataset
# df_sorted = df.sort_values(by = 'service', ascending = False, inplace = True)
# df_sorted.head()

# %%
#Sort the data using 2 or more columns
df_sorted = df.sort_values(by = ['rank', 'salary'], ascending = [True, False])
df_sorted.head(5)
# Out:
#          rank discipline  phd  service     sex  salary
# 34  AssocProf          B   12        8    Male  119800
# 62  AssocProf          B   14        7  Female  109650
# 30  AssocProf          B    9        7    Male  107008
# 74  AssocProf          B   19        6  Female  104542
# 59  AssocProf          B   12       10  Female  103994

# %% [markdown]
# ## Missing Values
# ## Missing values are marked as NaN

# %%
# Read the flight dataset
flights = pd.read_csv("flights.csv")
flights.head(30)
# Out:
#     year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0   2013      1    1     517.0        2.0     830.0       11.0      UA
# 1   2013      1    1     533.0        4.0     850.0       20.0      UA
# 2   2013      1    1     542.0        2.0     923.0       33.0      AA
# 3   2013      1    1     554.0       -6.0     812.0      -25.0      DL
# 4   2013      1    1     554.0       -4.0     740.0       12.0      UA
# 5   2013      1    1     558.0       -2.0     753.0        8.0      AA
# 6   2013      1    1     558.0       -2.0     924.0        7.0      UA
# 7   2013      1    1     558.0       -2.0     923.0      -14.0      UA
# 8   2013      1    1     559.0       -1.0     941.0       31.0      AA
# 9   2013      1    1     559.0       -1.0     854.0       -8.0      UA
# 10  2013      1    1     602.0       -8.0     812.0       -8.0      DL
# 11  2013      1    1     606.0       -4.0     858.0      -12.0      AA
# ...

# %%
# Select the rows that have atleast one missing value
flights[flights.isnull().any(axis=1)].head(15)
# Out:
#       year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 330   2013      1    1    1807.0       29.0    2251.0        NaN      UA
# 403   2013      1    1       NaN        NaN       NaN        NaN      AA
# 404   2013      1    1       NaN        NaN       NaN        NaN      AA
# 855   2013      1    2    2145.0       16.0       NaN        NaN      UA
# 858   2013      1    2       NaN        NaN       NaN        NaN      AA
# 859   2013      1    2       NaN        NaN       NaN        NaN      AA
# 860   2013      1    2       NaN        NaN       NaN        NaN      UA
# 1067  2013      1    3    1348.0       -2.0    1821.0        NaN      DL
# 1275  2013      1    3       NaN        NaN       NaN        NaN      AA
# 1276  2013      1    3       NaN        NaN       NaN        NaN      AA
# 1277  2013      1    3       NaN        NaN       NaN        NaN      AA
# 1278  2013      1    3       NaN        NaN       NaN        NaN      AA
# ...

# %% [markdown]
# ## Missing values methods
# ### dropna() - Drop missing observations
# ### dropna(how='all') - Drop observations where all cells is NA
# ### dropna(axis=1, how='all') - Drop column if all the values are missing
# ### dropna(thresh = 5) - Drop rows that contain less than 5 non-missing values
# ### fillna(0)-Replace missing values with zeros
# ### isnull()-returns True if the value is missing
# ### notnull()-Returns True for non-missing values

# %%
# Filter all the rows where arr_delay value is missing:
flights1 = flights[ flights['arr_delay'].notnull( )]
flights1.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
# 4  2013      1    1     554.0       -4.0     740.0       12.0      UA  N39463
#
#    flight origin dest  air_time  distance  hour  minute
# 0    1545    EWR  IAH     227.0      1400   5.0    17.0
# 1    1714    LGA  IAH     227.0      1416   5.0    33.0
# 2    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3     461    LGA  ATL     116.0       762   5.0    54.0
# 4    1696    EWR  ORD     150.0       719   5.0    54.0

# %%
# Remove all the observations with missing values
flights2 = flights.dropna()
flights2
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0       2013      1    1     517.0        2.0     830.0       11.0      UA
# 1       2013      1    1     533.0        4.0     850.0       20.0      UA
# 2       2013      1    1     542.0        2.0     923.0       33.0      AA
# 3       2013      1    1     554.0       -6.0     812.0      -25.0      DL
# 4       2013      1    1     554.0       -4.0     740.0       12.0      UA
# 5       2013      1    1     558.0       -2.0     753.0        8.0      AA
# 6       2013      1    1     558.0       -2.0     924.0        7.0      UA
# 7       2013      1    1     558.0       -2.0     923.0      -14.0      UA
# 8       2013      1    1     559.0       -1.0     941.0       31.0      AA
# 9       2013      1    1     559.0       -1.0     854.0       -8.0      UA
# 10      2013      1    1     602.0       -8.0     812.0       -8.0      DL
# ...

# %%
# Fill missing values with zeros
nomiss =flights['dep_delay'].fillna(0)
nomiss.isnull().any()
# Out:
# False

# %%
# Count how many missing data are in dep_delay and arr_delay columns

# %% [markdown]
# ## Aggregation Functions in Pandas
# ### min-minimum, max-maximum, count-number of non-null observations, sum-sum of values, mean-arithmetic mean of values,
# ### median-median, mad-mean absolute deviation, mode-mode, prod-product of values, std-standard deviation, var-unbiased variance
# ## Basic descriptive Stat
# ### sem-standard error of mean, skew-sample skewness, kurt-kurtosis, quantile value at %

# %%
#describe mtd - Basic statistics (count, mean, std, min, quantiles, max)
# Find the number of non-missing values in each column
flights.describe()
# Out:
#            year          month            day       dep_time      dep_delay  \
# count  160754.0  160754.000000  160754.000000  158418.000000  158418.000000
# mean     2013.0       6.547395      15.716567    1316.146006       9.463773
# std         0.0       3.410001       8.762794     470.823715      36.545109
# min      2013.0       1.000000       1.000000       1.000000     -33.000000
# 25%      2013.0       4.000000       8.000000     855.000000      -5.000000
# 50%      2013.0       7.000000      16.000000    1345.000000      -2.000000
# 75%      2013.0      10.000000      23.000000    1725.000000       7.000000
# max      2013.0      12.000000      31.000000    2400.000000    1014.000000
#
#             arr_time      arr_delay         flight       air_time  \
# count  158275.000000  157927.000000  160754.000000  157927.000000
# mean     1517.471161       2.094537    1156.344987     180.685158
# std       510.695413      41.479349     695.884283      97.507866
# ...

# %%
# Find mean value for all the columns in the dataset
flights.min()
# Out:
# year         2013
# month           1
# day             1
# dep_time        1
# dep_delay     -33
# arr_time        1
# arr_delay     -75
# carrier        AA
# flight          1
# origin        EWR
# dest          ANC
# air_time       21
# distance       17
# hour            0
# minute          0
# dtype: object

# %%
#agg() method are useful when multiple statistics are computed per column
flights[['dep_delay','arr_delay']].agg(['min','mean','max'])
# Out:
#         dep_delay    arr_delay
# min    -33.000000   -75.000000
# mean     9.463773     2.094537
# max   1014.000000  1007.000000

# %%
# Let's compute summary statistic per a group':
flights.groupby('carrier')['dep_delay'].mean()
# Out:
# carrier
# AA     8.586016
# AS     5.804775
# DL     9.264505
# UA    12.106073
# US     3.782418
# Name: dep_delay, dtype: float64

# %%
# Let's compute summary statistic per a group':
flights.groupby('carrier')['dep_time', 'dep_delay'].mean()
# Out:
#             dep_time  dep_delay
# carrier
# AA       1297.334434   8.586016
# AS       1294.561798   5.804775
# DL       1351.056155   9.264505
# UA       1327.136929  12.106073
# US       1231.332511   3.782418

# %%
# An example of computing different statistics for different columns
flights.agg({'dep_delay':['min','mean',max], 'carrier':['nunique']})
# Out:
#            dep_delay  carrier
# max      1014.000000      NaN
# mean        9.463773      NaN
# min       -33.000000      NaN
# nunique          NaN      5.0

# %%
# find the index of the maximum or minimum value
# if there are multiple values matching idxmin() and idxmax() will return the first match
flights['dep_delay'].idxmin()  #minimum value
# Out:
# 54111

# %%
# Count the number of records for each different value in a vector
flights['carrier'].value_counts()
# Out:
# UA    58665
# DL    48110
# AA    32729
# US    20536
# AS      714
# Name: carrier, dtype: int64
